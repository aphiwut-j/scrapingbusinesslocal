# %%
import pandas as pd

# %%
df = pd.read_csv('scraped_content_20240828_162204.csv')
df.head()
# Out:
#                                                  url  \
# 0                      http://topnotchroofing.com.au
# 1                          https://www.cryoprep.com/
# 2               https://www.vitachiropractic.com.au/
# 3  https://will-build-builder-carpenter.business....
# 4                       https://e1poolcertifier.com/
#
#                                         page_content about  \
# 0                                                NaN   NaN
# 1                                                NaN   NaN
# 2  Vita Chiropractic - Chiropractor Services Chir...   NaN
# 3                                                NaN   NaN
# 4  Pool Certifier Sydney | Pool Inspections and C...   NaN
#
#                                              contact
# 0                                                NaN
# 1                                                NaN
# 2  Service Chiro Newstead Sacro Occipital Technic...
# 3                                                NaN
# ...

# %%
df.isna().sum()
# Out:
# url              0
# page_content    23
# about           72
# contact         63
# dtype: int64

# %%
df[df['about'].notna()].to_csv('test.csv', index=False)
# Out:
#                                                   url  \
# 6                       http://superiorfencing.com.au
# 8                 https://www.industrialsteel.com.au/
# 12                           http://artandyou.com.au/
# 14                                http://sced.com.au/
# 21                       https://www.icepower.com.au/
# 22                    http://perthcremationswa.com.au
# 26                    https://www.grothconstruct.com/
# 27                   https://aussiediscreetstore.com/
# 32                   https://www.beachstherapy.com.au
# 33                          https://maitriclinic.com/
# 35                  https://munnoparaconcrete.com.au/
# 39                       http://paradisemarriages.com
# 44  https://www.facebook.com/www.golfclubtumba.com...
# 54  http://www.rowesbaygolfclub.com.au/?utm_source...
# 58                     http://www.moegolfclub.com.au/
# 59  https://www.golf.org.au/?utm_source=gmb&utm_me...
# ...

# %%
df[df['about'].notna()].to_csv('test.csv', index=False)
