# %%
import pandas as pd

# %%
path='/Users/aphiwutjanphet/Documents/internship/Business Local/github/scrapingbusinesslocal/combined/output/cleant json/cleaned_content_20240905_163659.csv'

# %%
df = pd.read_csv(path)
df.head()
# Out:
#                                                  url  \
# 0                      http://topnotchroofing.com.au
# 1                          https://www.cryoprep.com/
# 2               https://www.vitachiropractic.com.au/
# 3  https://will-build-builder-carpenter.business....
# 4                       https://e1poolcertifier.com/
#
#                                         page_content  about_content  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2  Vita Chiropractic - Chiropractor Services Chir...            NaN
# 3                                                NaN            NaN
# 4  Pool Certifier Sydney | Pool Inspections and C...            NaN
#
#                                      contact_content  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
df.assign(number_found='', name_found='', email_found='', address_found='').to_csv('cleant json/output7.csv')

# %%
# df.head(5).to_csv('cleant json/tmp.csv', index=False)
