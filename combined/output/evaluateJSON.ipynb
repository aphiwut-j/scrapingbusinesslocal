# %%
import pandas as pd

# %%
path='/Users/aphiwutjanphet/Documents/internship/Business Local/github/scrapingbusinesslocal/combined/output/evaluation results/result_20240911_112018.csv'

# %%
df = pd.read_csv(path)
df.head()
# Out:
#                                                  url  \
# 0                      http://topnotchroofing.com.au
# 1                          https://www.cryoprep.com/
# 2               https://www.vitachiropractic.com.au/
# 3  https://will-build-builder-carpenter.business....
# 4                       https://e1poolcertifier.com/
#
#                                         page_content about_content  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2  Vita Chiropractic - Chiropractor Services Chir...           NaN
# 3                                                NaN           NaN
# 4  Pool Certifier Sydney | Pool Inspections and C...           NaN
#
#                                      contact_content  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
df[(df['number_found'] == 3) | (df['address_found'] == 3) | (df['name_found'] == 3) | (df['email_found'] == 3)]
# Out:
# Empty DataFrame
# Columns: [url, page_content, about_content, contact_content, emails_x, logo, error, emails_y, extracted_content, extracted_about, extracted_contact, number_found, address_found, name_found, email_found, extracted_content_Name, extracted_content_Address, extracted_content_Contact_Number, extracted_content_Email, extracted_content_About, extracted_contact_Name, extracted_contact_Address, extracted_contact_Contact_Number, extracted_contact_Email, extracted_contact_About, extracted_about_Name, extracted_about_Address, extracted_about_Contact_Number, extracted_about_Email, extracted_about_About]
# Index: []
#
# [0 rows x 30 columns]
