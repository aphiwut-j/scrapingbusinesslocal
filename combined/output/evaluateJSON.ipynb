# %%
import pandas as pd

# %%
path='/Users/aphiwutjanphet/Documents/internship/Business Local/github/scrapingbusinesslocal/combined/output/cleant json/cleaned_content_20240905_104905.csv'

# %%
df = pd.read_csv(path)
df.head()
# Out:
#                                     url  \
# 0  https://www.vitachiropractic.com.au/
# 1          https://e1poolcertifier.com/
# 2      https://charmaineiversen.com.au/
# 3         http://superiorfencing.com.au
# 4        https://wordofmouthglobal.com/
#
#                                         page_content  \
# 0  Vita Chiropractic - Chiropractor Services Chir...
# 1  Pool Certifier Sydney | Pool Inspections and C...
# 2  Charmaine Iversen Kinesiology & Natural Therap...
# 3  Account Suspended\nAccount Suspended\nThis Acc...
# 4  Word of Mouth\nToggle navigation\nHome\nAbout ...
#
#                                            about_url  \
# 0                                                NaN
# 1  https://e1poolcertifier.com/about-the-certific...
# 2                                             #about
# 3                                                NaN
# 4                                                NaN
#
#                                        about_content  \
# ...
